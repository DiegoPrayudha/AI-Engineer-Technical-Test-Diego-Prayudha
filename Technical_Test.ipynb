# %%
pip install pdfplumber pandas
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting pdfminer.six==20250506 (from pdfplumber)
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber) (11.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20250506->pdfplumber) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20250506->pdfplumber) (43.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.23)
# Downloading pdfplumber-0.11.7-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.3 MB/s eta 0:00:00
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 49.7 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 48.8 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20250506 pdfplumber-0.11.7 pypdfium2-4.30.0

# %% [markdown]
# # **Task 1**

# %%
import pdfplumber
import re
import pandas as pd
from pathlib import Path

def extract(pdf_path: str, start_page: int = 6, end_page: int = 8):
    results = []
    section, subsection = None, None
    buffer_line = ""

    with pdfplumber.open(pdf_path) as pdf:
        # Loop dari halaman yang diinginkan (ingat: index mulai dari 0)
        for page_num in range(start_page - 1, end_page):
            page = pdf.pages[page_num]
            width, height = page.width, page.height

            # Crop margin atas, kanan, bawah
            cropped = page.crop((0, 120, width - 120, height - 40))
            words = cropped.extract_words(extra_attrs=["fontname", "size"])

            # Gabungkan kata berdasarkan posisi Y (garis horizontal)
            lines = {}
            for w in words:
                line_y = round(w["top"], -1)
                lines.setdefault(line_y, []).append(w)
            lines = [sorted(v, key=lambda x: x["x0"]) for _, v in sorted(lines.items())]

            # Gabungkan teks per baris dan tandai apakah bold
            all_lines = []
            for line_words in lines:
                text = " ".join(w["text"] for w in line_words).strip()
                is_bold = any("Bold" in w["fontname"] or "Bd" in w["fontname"] or "Black" in w["fontname"]
                              for w in line_words)
                all_lines.append((text, is_bold))

            for i, (line_text, is_bold) in enumerate(all_lines):
                if not line_text:
                    continue

                tokens = re.findall(r"(?:[\d.,]+|–|-)", line_text)
                has_number = len(tokens) > 0
                next_line = all_lines[i + 1][0] if i + 1 < len(all_lines) else ""
                next_is_bold = all_lines[i + 1][1] if i + 1 < len(all_lines) else False
                next_has_number = bool(re.search(r"\d[\d.,]+", next_line))

                # === 1️⃣ SECTION ===
                if is_bold and not has_number and next_is_bold:
                    section = line_text.strip()
                    subsection = None
                    continue

                # === 2️⃣ SUBSECTION biasa ===
                if is_bold and not has_number and next_has_number:
                    subsection = line_text.strip()
                    continue

                # === 3️⃣ SUBSECTION TOTAL ===
                if is_bold and has_number and "TOTAL" in line_text.upper():
                    first_num = re.search(r"[\d.,]+", line_text)
                    if first_num:
                        subsection = line_text[:first_num.start()].strip()
                    else:
                        subsection = line_text.strip()

                    filtered = [n for n in tokens if len(n.replace(".", "").replace(",", "")) > 2 or n in ["-", "–"]]
                    if len(filtered) >= 2:
                        val_2021, val_2020 = filtered[-2], filtered[-1]
                        split_idx = line_text.rfind(val_2021)
                        item = line_text[:split_idx].strip()
                        results.append({
                            "page": page_num + 1,
                            "section": section,
                            "subsection": subsection,
                            "item": item,
                            "2021": val_2021,
                            "2020": val_2020
                        })
                    continue

                # === 4️⃣ ITEM biasa ===
                if not is_bold:
                    if not has_number:
                        buffer_line += " " + line_text
                        continue
                    if buffer_line:
                        line_text = buffer_line.strip() + " " + line_text
                        buffer_line = ""

                    filtered = [n for n in tokens if len(n.replace(".", "").replace(",", "")) > 2 or n in ["-", "–"]]
                    if len(filtered) >= 2:
                        val_2021, val_2020 = filtered[-2], filtered[-1]
                        split_idx = line_text.rfind(val_2021)
                        item = line_text[:split_idx].strip()
                        results.append({
                            "page": page_num + 1,
                            "section": section,
                            "subsection": subsection,
                            "item": item,
                            "2021": val_2021,
                            "2020": val_2020
                        })

    # Simpan hasil ke CSV
    Path("output").mkdir(exist_ok=True)
    df = pd.DataFrame(results)
    df.to_csv("output/extracted.csv", index=False, encoding="utf-8-sig")

    print(f"✅ Extraction selesai — {len(df)} baris dari halaman {start_page}–{end_page} disimpan ke output/extracted.csv")
    return df


# === Jalankan ===
df_page = extract("EKAD - LAPORAN KEUANGAN TAHUNAN 2021.pdf", start_page=6, end_page=8)
df_page
# Out:
# ✅ Extraction selesai — 51 baris dari halaman 6–8 disimpan ke output/extracted.csv
#     page            section         subsection  \
# 0      6               ASET        ASET LANCAR
# 1      6               ASET        ASET LANCAR
# 2      6               ASET        ASET LANCAR
# 3      6               ASET        ASET LANCAR
# 4      6               ASET        ASET LANCAR
# 5      6               ASET        ASET LANCAR
# 6      6               ASET        ASET LANCAR
# 7      6               ASET        ASET LANCAR
# 8      6               ASET        ASET LANCAR
# 9      6               ASET        ASET LANCAR
# 10     6               ASET        ASET LANCAR
# 11     6               ASET  ASET TIDAK LANCAR
# 12     6               ASET  ASET TIDAK LANCAR
# 13     6               ASET  ASET TIDAK LANCAR
# 14     6               ASET  ASET TIDAK LANCAR
# 15     6               ASET  ASET TIDAK LANCAR
# 16     6               ASET  ASET TIDAK LANCAR
# 17     6               ASET  ASET TIDAK LANCAR
# 18     6               ASET  ASET TIDAK LANCAR
# 19     6               ASET  ASET TIDAK LANCAR
# 20     6               ASET         TOTAL ASET
# 21     7  LIABILITAS JANGKA             PENDEK
# 22     7  LIABILITAS JANGKA             PENDEK
# 23     7  LIABILITAS JANGKA             PENDEK
# 24     7  LIABILITAS JANGKA             PENDEK
# 25     7  LIABILITAS JANGKA             PENDEK
# 26     7  LIABILITAS JANGKA             PENDEK
# 27     7  LIABILITAS JANGKA             PENDEK
# 28     7  LIABILITAS JANGKA             PENDEK
# 29     7  LIABILITAS JANGKA             PENDEK
# 30     7  LIABILITAS JANGKA             PENDEK
# 31     7  LIABILITAS JANGKA             PENDEK
# 32     7  LIABILITAS JANGKA               None
# 33     7  LIABILITAS JANGKA               None
# 34     7  LIABILITAS JANGKA               None
# 35     7  LIABILITAS JANGKA               None
# 36     7  LIABILITAS JANGKA               None
# 37     7  LIABILITAS JANGKA   TOTAL LIABILITAS
# 38     8          Catatan /               None
# 39     8          Catatan /               None
# 40     8          Catatan /               None
# 41     8          Catatan /               None
# 42     8          Catatan /               None
# 43     8          Catatan /               None
# 44     8          Catatan /               None
# 45     8          Catatan /               None
# 46     8          Catatan /               None
# 47     8          Catatan /               None
# 48     8          Catatan /               None
# 49     8          Catatan /               None
# 50     8          Catatan /               None
#
#                                                  item               2021  \
# 0                             Kas dan setara kas 4,33    360.662.679.743
# 1   Deposito berjangka yang dibatasi penggunaannya...     24.219.914.929
# 2                           31 Desember 2021 dan 2020     83.071.117.010
# 3                                   Pihak berelasi 30        684.677.718
# 4                                   Piutang lain-lain                  -
# 5                                        pihak ketiga        254.139.325
# 6                                          dan 2020 7    168.288.992.651
# 7                           Pajak dibayar di muka 16a         11.330.792
# 8               Beban dibayar di muka dan uang muka 8      5.864.472.120
# 9                              Aset lancar lainnya 33        716.097.870
# 10                                  Total aset lancar    643.773.422.158
# 11           Piutang lain-lain - pihak berelasi 30,33        199.841.850
# 12                  Investasi pada entitas asosiasi 9        580.172.455
# 13  Aset keuangan pada nilai wajar melalui penghas...     53.136.538.636
# 14                       31 Desember 2021 dan 2020 11    459.573.571.345
# 15                       31 Desember 2021 dan 2020 12        511.213.187
# 16                 Uang muka perolehaan aset tetap 13      6.235.779.401
# 17   Taksiran tagihan restitusi pajak penghasilan 16b                  –
# 18                           Aset pajak tangguhan 16d      1.554.206.231
# 19                            Total aset tidak lancar    521.791.323.105
# 20                                         TOTAL ASET  1.165.564.745.263
# 21  Catatan bagian yang atas laporan tidak terpisa...     28.907.055.212
# 22                                       Pihak ketiga     31.551.310.050
# 23                                  Pihak berelasi 30      2.017.320.396
# 24                                 Utang lain-lain 32      1.278.821.167
# 25                                    Utang pajak 16c      9.340.820.989
# 26       Liabilitas imbalan kerja jangka pendek 17,33      4.752.467.212
# 27                                 Beban akrual 18,33      1.829.495.271
# 28                                   Utang dividen 33      1.072.127.413
# 29  Liabilitas jangka panjang yang jatuh tempo dal...      1.476.443.476
# 30                                 Liabilitas sewa 19        755.220.593
# 31                     Total liabilitas jangka pendek     82.981.081.779
# 32  setelah dikurangi bagian yang akan jatuh tempo...      1.897.912.636
# 33                                 Liabilitas sewa 19     17.553.474.622
# 34                     Liabilitas pajak tangguhan 16d      4.591.921.620
# 35                  Liabilitas imbalan pasca kerja 17     28.140.908.542
# 36                    Total liabilitas jangka panjang     52.184.217.420
# 37                                   TOTAL LIABILITAS    135.165.299.199
# 38                                        Modal dasar                  -
# 39  Modal ditempatkan dan disetor Is penuh - 698.7...     34.938.750.000
# 40              Tambahan modal disetor 21 138.490.000        138.490.000
# 41  Komponen ekuitas lain : Othe Selisih transaksi...      3.528.637.968
# 42  Selisih kurs karena E penjabaran laporan tr ke...     13.072.283.357
# 43  Keuntungan yang belum direalisasi atas perubah...     30.777.817.918
# 44  Pengukuran kembali liabilitas imbalan pasca ke...      6.202.022.525
# 45                       dari akumulasi penyusutan 11    274.004.704.278
# 46  Saldo laba Telah ditentukan Penggunaannya 7.20...      7.200.000.000
# 47                     Belum ditentukan Penggunaannya    646.926.708.288
# 48  Total ekuitas yang dapat T diatribusikan kepad...    998.239.584.239
# 49                      Kepentingan non-pengendali 23     32.159.861.825
# 50                                      Total ekuitas  1.030.399.446.064
#
#                  2020
# 0     348.026.902.985
# 1      21.103.842.879
# 2      87.196.198.463
# 3         581.104.437
# 4                   -
# 5         986.432.198
# 6      86.409.350.807
# 7         472.020.184
# 8       6.980.448.125
# 9         737.558.020
# 10    552.493.858.098
# 11        274.104.730
# 12        569.925.887
# 13     47.379.663.055
# 14    474.173.694.707
# 15        608.507.000
# 16      2.849.525.000
# 17         79.316.000
# 18      3.551.225.909
# 19    529.485.962.288
# 20  1.081.979.820.386
# 21      9.783.967.560
# 22     23.690.943.245
# 23      1.979.059.727
# 24      1.055.817.614
# 25     17.326.789.738
# 26      5.129.108.697
# 27      2.650.144.449
# 28        846.702.744
# 29      4.973.128.138
# 30        731.096.396
# 31     68.166.758.308
# 32      3.449.111.321
# 33     18.714.304.552
# 34      4.483.794.698
# 35     34.803.293.845
# 36     61.450.504.416
# 37    129.617.262.724
# 38      1.600.000.000
# 39     34.938.750.000
# 40        138.490.000
# 41      3.528.637.968
# 42     16.283.775.681
# 43     26.287.454.965
# 44                  -
# 45    276.302.451.162
# 46      7.200.000.000
# 47    571.664.170.983
# 48    923.084.432.298
# 49     29.278.125.364
# 50    952.362.557.662

# %% [markdown]
# # **Task 2**

# %%
from pathlib import Path

Path("output").mkdir(exist_ok=True)

filtered_df = df_page[
    df_page["item"].str.contains(r"\btotal\b", case=False, na=False) &
    (df_page["item"].str.split().str.len() <= 5)
]

filtered_subset = filtered_df[["item", "2021", "2020"]]

output_path = "output/filtered_total.json"
filtered_subset.to_json(output_path, orient="records", force_ascii=False, indent=2)

print(f"✅ Disimpan ke {output_path} ({len(filtered_subset)} baris)")
# Out:
# ✅ Disimpan ke output/filtered_total.json (7 baris)
